# %% [markdown]
# # Proyectos II - Proyecto de Datos
#
# ### Introducción
#
# La práctica de la parte de Data de la asignatura trataba un problema de regresión en el que se pedía predecir el precio de venta (`sale_price`) de las viviendas utilizando para ello `dataset.csv`. En este Notebook se deben contestar a una serie de preguntas sobre los contenidos de la parte de datos de la asignatura utilizando para ello el dataset mencionado previamente.

# %% [markdown]
# En primer lugar importamos las librerías necesarias

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Y creamos el `DataFrame`con los datos

# %%
df = pd.read_csv('dataset.csv',index_col='row_id')

# %% [markdown]
# ### Cuestiones
#
# El valor de cada pregunta es el mismo (_1 punto_). Puedes añadir tantas celdas (tanto de código como Markdown) como consideres necesarias.

# %% [markdown]
# #### 1. ¿Qué gráfico usarías para analizar la distribución de `sale_price`? Muéstralo.

# %%
pd.

# %% [markdown]
# #### 2. ¿Cómo es la distribución de `sale_prize`? ¿Qué significa eso?
#
# #### ¿Crees necesario aplicar alguna transformación? En caso afirmativo, ¿cuál? y ¿por qué motivo? Muéstralo.

# %% [markdown]
# #### 3. ¿Hay valores missing en la columna `sale_nbr`?
#
# #### `sale_nbr` representa el número de veces que una vivienda ha sido revendida. ¿Podríamos eliminarla directamente? ¿Cuál sería la mejor manera de tratarla? Muéstralo.

# %% [markdown]
# #### 4. ¿Qué problema hay si imputamos missing antes de dividir el conjunto en train/test? Explica lo que sepas sobre este problema.

# %% [markdown]
# #### 5. ¿Qué significa que dos variables tengan una correlación alta y positiva? ¿Una correlación baja implica que la variable es inútil para el modelo? Pon algún ejemplo de estos casos en el dataset.

# %% [markdown]
# #### 6. ¿Qué diferencia hay entre una variable numérica y una categórica? ¿Qué sucede con las variables categóricas durante el modelado? ¿Cómo se tratan? ¿Hay variables categóricas en este dataset?
#
# #### ¿Qué problema pueden generar las variables categóricas con demasiados valores únicos?

# %% [markdown]
# #### 7. ¿Qué es Feature Engineering? ¿Por qué puede ser útil crear una variable como `total_baths`? Pon otro ejemplo de Feature Engineering útil para este dataset.

# %% [markdown]
# -------------------------------------------
#
# Ahora cargamos las variables `y_train`, `y_validation` e `y_pred` por si fueran necesarias.

# %%
y_train = np.load("y_train.npy")
y_validation = np.load("y_validation.npy")
y_pred = np.load("y_pred.npy")

# %% [markdown]
# #### 8. ¿Qué es un modelo baseline? ¿Por qué es importante comparar cualquier modelo con el baseline? ¿Sabrías definir uno para este problema?

# %% [markdown]
# #### 9. ¿Qué diferencia hay entre parámetros e hiperparámetros? ¿Qué hiperparámetros importantes tiene un Random Forest?

# %% [markdown]
# #### 10. ¿Qué información aporta un gráfico True vs Predicted? Muéstralo para las variables `y_validation` e `y_pred` y comenta los resultados.

# %% [markdown]
# `histplot`, `xlabel`, `ylabel`, `log1p`, `fillna`, `corr`, `heatmap`, `scatter`, `plt.show()`
